# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 1
# #### Nombre y Apellido
# Fabian Catuogno
# ***
# ## Muestreo de señales - Fourier

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Se busca realizar una librería en Python que nos permita obtener $N$ muestras de las siguientes señales de período $T_0=1/f_0$, muestreadas a una frecuencia $f_s$ :
#
# </div>

# %% [markdown]
# + **Senoidal**
#
# > $s(k)=A_0.sin(2\pi.k.\frac{ f_0}{f_s} + \phi_0),\space\space \forall k \in \Bbb{R} \wedge k \in (0, N-1)$
#
# + __Ruido__ incorrelado de distribución Gaussiana y parámetros $\mu$ y $\sigma^2$
#
# ***
#
# + (Opcional) __Cuadrada__ con ciclo de actividad $d \in (0,1)$
#
# > $s(k)=A_0,\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=-A_0,\space \forall k \in (N.d, N-1)$
#
# + (Opcional) __Triangular__ con punto de simetría $d \in (0,1)$ y coeficientes $a_{ij} \in \Bbb{R}$
#
# > $s(k)=a_{11}.k/f_s+a_{12},\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=a_{21}.k/f_s+a_{22},\space \forall k \in (N.d, N-1)$

# %% [markdown]
# Es decir que se podría invocar la señal que genere la senoidal de la siguiente manera:

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas import DataFrame
from IPython.display import HTML


#Config Tamaño de Plots
plt.rcParams['figure.figsize'] = [16, 8]

#def generador_senoidal (fs, f0, N, a0=1, p0=0):
""" 

brief:  Generador de señales senoidal, con argumentos

fs:     frecuencia de muestreo de la señal [Hz]
N:      cantidad de muestras de la señal a generar
f0:     frecuencia de la senoidal [Hz]
a0:     amplitud pico de la señal [V]
p0:     fase de la señal sinusoidal [rad]

como resultado la señal devuelve:

signal: senoidal evaluada en cada instante 
tt:     base de tiempo de la señal
"""    

    # comienzo de la función

def mi_funcion_sen( vmax, dc, ff, ph, nn, fs):
    '''Genera una senial senoidal con los parametros indicados.

    Keyword arguments:
    vmax -- Valor pico de la senoidal
    dc -- componente de continua de la senial
    ff -- frecuencia de la senial
    ph -- fase de la senial
    nn -- numero de muestras de la senial
    fs - frecuencia de muestro de la senial
                                

    Returns: array of float, array of float

    '''  
    tt = np.arange(0.0, nn/fs, 1/fs)
    
    xx = dc + vmax*np.sin((2*np.pi*ff*tt+ph))
    
    return(tt, xx)

def GaussNoise(N,media,varianza):
    '''Genera una senial de ruido entre 0 y 1seg con distribucion gausiana
        con los parametros indicados.
        
    N -- Cantidad de muestras
    media -- media
    Varianza --varianza 
                         

    Returns: array of float, array of float

    '''
    signal = np.random.normal(media, varianza, N)

    return signal
    
    
    # fin de la función

#Defincion Param.

N = 512
A = 1
Offset = 0
PHI = 0
Fs = 200
    
#LLamados a funcion

ruido = GaussNoise(N,0,1)
ruido2 = GaussNoise(N,0,1.028)
ruido3 = GaussNoise(N,0,0.935)

tt = np.arange(0,1,1/N)

N = 200

tiempo, seno = mi_funcion_sen( A, Offset, 3, PHI, N, Fs)
tiempo, seno2 = mi_funcion_sen( A, Offset, 6, PHI, N, Fs)
tiempo, seno3 = mi_funcion_sen( A, Offset, 9, PHI, N, Fs)

#Generacion de gráficas
#Ruido
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot(tt,ruido, label='μ=0 σ²=1')   # Plot some data on the axes.
ax.plot(tt,ruido2, label='μ=0 σ²=1.028')  # Plot some data on the axes.
ax.plot(tt,ruido3, label='μ=0 σ²=0.935')  # Plot some data on the axes.

ax.set_xlabel('Tiempo [segundos]')           # and here?
ax.set_ylabel('Amplitud [V]')          # and here?
ax.set_title('Señal: Ruido', fontsize='x-large')   # and here?
ax.legend(loc='upper right', fontsize='x-large')  # Add a legend.


#Senos
fig2, ax2 = plt.subplots()  # Create a figure containing a single axes.
ax2.plot(tiempo,seno, label='3 Hz')   # Plot some data on the axes.
ax2.plot(tiempo,seno2, label='6 Hz')  # Plot some data on the axes.
ax2.plot(tiempo,seno3, label='9 Hz')  # Plot some data on the axes.

ax2.set_xlabel('Tiempo [segundos]')           # and here?
ax2.set_ylabel('Amplitud [V]')          # and here?
ax2.set_title('Señal: Senoidal', fontsize='x-large')   # and here?
ax2.legend(loc='upper right', fontsize='x-large')  # Add a legend.
plt.show()

# %% [markdown]
# a) Genere las gráficas asociadas a las siguientes señales de ejemplo para corroborar el correcto funcionamiento de las funciones. Para la presentación de las mismas, tome como referencia la presentación de la siguiente señal respecto a:
#
# * etiquetas indicando cada eje con sus respectivas unidades
# * leyendas indicando cada trazo o color qué representa
# * título de la figura que explique lo que se pretende visualizar
#
#
# <img src="./fig_ejemplo.svg" align="center" width="100%" />
# <img src="./fig_ejemplo2.svg" align="center" width="70%" />

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from pandas import DataFrame
from IPython.display import HTML

# Insertar aquí el código para inicializar tu notebook
########################################################

# %%
# NO modifiques este bloque
############################

N  = 1000 # muestras
fs = 1000 # Hz

# %%
##################
# a.1) Senoidal #
#################

a0 = 1 # Volts
p0 = 0 # radianes
f0 = 10   # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tiempo, tension = mi_funcion_sen( a0, 0, f0, p0, N, fs)

plt.figure(1)
line_hdls = plt.plot(tiempo, tension)
plt.title('Señal Senoidal:', fontsize='x-large')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
# plt.grid(which='both', axis='both')

# presentar una leyenda para cada tipo de señal
axes_hdl = plt.gca()

plt.show()

# %% [markdown]
# ¿Podría inferir la frecuencia de la senoidal a.1 a partir de su representación temporal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p> Es Posible inferir la frecuencia de la señal a partir de la gráfica, contando la cantidad de ciclos contenidos en la unidad de tiempo representada </p>
# </div>

# %%
##################
# a.2) Senoidal #
#################

a0 = 1 # Volts
p0 = 0 # radianes
f0 = fs/2   # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tiempo, tension = mi_funcion_sen( a0, 0, f0, p0, N, fs)

plt.figure(1)
line_hdls = plt.plot(tiempo, tension)
plt.title('Señal Senoidal:', fontsize='x-large')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
#    plt.grid(which='both', axis='both')

# presentar una leyenda para cada tipo de señal
axes_hdl = plt.gca()

plt.show()

# %%
##################
# a.3) Senoidal #
#################

a0 = 1       # Volts
p0 = np.pi/2 # radianes
f0 = fs/2    # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tiempo, tension = mi_funcion_sen( a0, 0, f0, p0, N, fs)

plt.figure(1)
line_hdls = plt.plot(tiempo, tension)
plt.title('Señal Senoidal:', fontsize='x-large')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
#    plt.grid(which='both', axis='both')

#plt.xlim(0, 0.02)

plt.show()

# %% [markdown]
# ¿Y para los casos **a.2** y **a.3** podría conocer los parámetros de la senoidal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>En ninguno de los dos casos es posible interpretar correctamente las señales que se pretendía representar, ni sus parametros </p>
# </div>

# %% [markdown]
# ¿A qué se debe?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b>
# <p> En ambos casos se está "muestreando" a una frecuencia igual a Nyquist. Para el primer caso, en el punto a.2 lo que ocurre es que la señal esta siendo evaluada justo en sus cruces por cero. Lo que terminamos observando es la figura que se forma de la representacion de los valores devueltos por la función sin() de numpy, propios de como está implementada esta función y de la presición del tipo de variable utilizada </p>
# <p>Por otro lado en el punto a.3 la señal es evaluada en sus picos, que tratandose de un seno de amplitud unitaria resulta en un grafico que alterna entre 1 y -1. Dejando a un lado que debido a la gran frecuencia de la señal termina observandose "una mancha rectangular", si hicieramos un "zoom" de la señal podriamos inferir su frecuencia a partir de la gráfica. Sin embargo observaríamos una representacion distorsionada, ya que con los puntos muestreados resulta representada una triangular. Otro punto a mencionar es que sin conocer la señal de antemano sería imposible determinar la amplitud de la senoidal, ya que siempre tendremos un valor fijo que alterna en signo, dependiente de en que momento/fase de la señal se esté muestreando
# </div>

# %%
##################
# a.4) Senoidal #
#################

a0 = 1     # Volts
p0 = 0     # radianes
f0 = fs+10 # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tiempo, tension = mi_funcion_sen( a0, 0, f0, p0, N, fs)

plt.figure(1)
line_hdls = plt.plot(tiempo, tension)
plt.title('Señal Senoidal:', fontsize='x-large')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
#    plt.grid(which='both', axis='both')

# presentar una leyenda para cada tipo de señal
axes_hdl = plt.gca()

plt.show()

# %% [markdown]
# ¿Es posible diferenciar **a.1** de **a.4** a partir de las gráficas?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b>
#     <p>No es posible diferenciarlas a partir de las gráficas. Esto es producto del fenomeno conocido como aliasing. </p>
# </div>

# %% [markdown]
# ¿En caso que no, qué solución podría implementar para evitar dicha ambigüedad?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>En el caso practico la manera de evitar esta ambiguedad es acotandonos en banda antes de ingresar al elemento que producirá el muestreo de nuestra señal. Más concretamente podemos hablar de un filtro LPF implementado a modo de anti alias, para realizar parte del acondincionamiento de la señal antes de ingresar al ADC. </p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.a)</b> (Opcional) Implemente un algoritmo que calcule la transformada discreta de Fourier (DFT). Utilice las funciones generadoras de señales de 1) para evaluar y ejemplificar su funcionamiento.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.b)</b> (Opcional) Compare el tiempo de ejecución de la DFT implementada en con la **FFT** (implementada en **scipy.signal**) en función del tamaño de la señal N. Grafique el tiempo de ejecución de ambos casos en función de N.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Utilice el módulo **timeit** para medir el tiempo transcurrido.
# </div>

# %%
import time

the_start = time.time()
print("hello")
the_end = time.time()
print(the_start - the_end)

def DFT(x):
    '''Retorna Transformada de Fourier Discreta de la secuencia brindada.

    Keyword arguments:
    x -- Secuencia a la cual se le calcula la DFT
                                

    Returns: array of complex

    '''  
    
    N = len(x)
    
    X = np.zeros(N, complex)

    for m in np.arange(N):
        for n in np.arange(N):
            X[m] += np.complex(x[n])*np.exp(-2j*np.pi*n*m/N)
            
    
    return X
# Out:
# hello
# -9.369850158691406e-05

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
from pandas import DataFrame
from IPython.display import HTML

#######################################
# Tu simulación que genere resultados #
#######################################

NN = [16, 32, 64, 128, 256, 512, 1024, 2048]
tus_resultados = [['--','--']]

for nn in NN:
    tiempo, tension = mi_funcion_sen( a0, 0, f0, p0, nn, fs)
    
    the_start = time.time()
    DFT(tension)
    the_end = time.time()
    
    the_startF = time.time()
    np.fft.fft(tension)
    the_endF = time.time()

    tus_resultados.append([str(the_end-the_start),str(the_endF-the_startF)])


#tus_resultados = [ ['1'], 
#                   ['2'], # <-- acá debería haber numeritos :)
#                   ['3'], # <-- acá debería haber numeritos :)
#                   ['4'], # <-- acá debería haber numeritos :)
#                   ['5'], # <-- acá debería haber numeritos :)
#                   ['6'], # <-- acá debería haber numeritos :)
#                   ['7'], # <-- acá debería haber numeritos :)
#                   ['8'], # <-- acá debería haber numeritos :)
#                   ['9']  # <-- acá debería haber numeritos :)
#                 ]

df = DataFrame(tus_resultados, columns=['tiempo transcurrido (s) DFT', 'tiempo transcurrido (s) FFT'],
               index=['Tamaño de la señal N', 
                      16, 
                      32, 
                      64, 
                      128,
                      256,
                      512,
                      1024,
                      2048
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tiempo transcurrido (s) DFT</th>
#       <th>tiempo transcurrido (s) FFT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tamaño de la señal N</th>
#       <td>--</td>
#       <td>--</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.001974821090698242</td>
#       <td>8.702278137207031e-05</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>0.00647425651550293</td>
#       <td>0.00016236305236816406</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>0.022136926651000977</td>
#       <td>7.462501525878906e-05</td>
#     </tr>
#     <tr>
#       <th>128</th>
#       <td>0.08754181861877441</td>
#       <td>4.2438507080078125e-05</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td>0.32596850395202637</td>
#       <td>0.00011491775512695312</td>
#     </tr>
#     <tr>
#       <th>512</th>
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.a)</b> Verifique el efecto del leakage para una senoidal de $f_0 = f_S/4 + f_D$ siendo $f_D = (0.01,\, 0.25,\, 0.5)$, es decir una frecuencia de desintonía respecto al bin $f_S/4$.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
from pandas import DataFrame
from IPython.display import HTML

#######################################
# Tu simulación que genere resultados #
#######################################

Offset = 0
N = 1000

tus_resultados = [ ['$ \lvert X(f_0) \lvert$', '$ \lvert X(f_0+1) \lvert $', '$\sum_{i=F} \lvert X(f_i) \lvert ^2 $'], 
                   ['',                        '',                           '$F:f \neq f_0$']
                   ]
fd = [0, 0.01, 0.25, 0.5]

for f0 in fd:
    tiempo, xx = mi_funcion_sen( a0, Offset, fs/4+f0, p0, N, fs)
    
    ff = np.fft.fft(xx)
    modulo = np.abs(ff)/N
    frec = np.fft.fftfreq(N,1/N)
    
    fig, ax1 = plt.subplots()
    
    # ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
    ax1.stem(frec, 2*modulo, use_line_collection = True) #Escalo por dos ya que solo conservo lado derecho
    ax1.set_title('Espectro de la señal' , fontsize='x-large')
    ax1.set_ylabel('Modulo []')
    ax1.set_xlabel('Frec [K]')
    plt.xlim(240, 260)


    ax1.grid(True)
    
    potencia = (np.sum(modulo**2))
    print(potencia)
    
    tus_resultados.append([str(2*modulo[250]), str(2*modulo[251]), str(potencia-(2*(modulo[250]**2)))]) 
    
#tus_resultados = [ ['$ \lvert X(f_0) \lvert$', '$ \lvert X(f_0+1) \lvert $', '$\sum_{i=F} \lvert X(f_i) \lvert ^2 $'], 
#                  ['',                        '',                           '$F:f \neq f_0$'], 
#                  ['', '', ''], # <-- acá debería haber numeritos :)
#                  ['', '', ''], # <-- acá debería haber numeritos :)
#                  ['', '', ''], # <-- acá debería haber numeritos :)
#                  ['', '', '']  # <-- acá debería haber numeritos :)
#                  ]
df = DataFrame(tus_resultados, columns=['Frecuencia central', 'Primer adyacente', 'Resto de frecuencias'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '$f_S/4$', 
                      '$f_S/4+0.01$', 
                      '$f_S/4+0.25$', 
                      '$f_S/4+0.5$'])
HTML(df.to_html())
# Out:
# 0.5000000000000002
# 0.49999803064405834
# 0.49949999999999983
# 0.5000000000000002
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Frecuencia central</th>
#       <th>Primer adyacente</th>
#       <th>Resto de frecuencias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$ \lvert X(f_0) \lvert$</td>
#       <td>$ \lvert X(f_0+1) \lvert $</td>
#       <td>$\sum_{i=F} \lvert X(f_i) \lvert ^2 $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$F:f \neq f_0$</td>
#     </tr>
#     <tr>
#       <th>$f_S/4$</th>
#       <td>1.0000000000000002</td>
#       <td>2.023234201892594e-14</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.01$</th>
#       <td>0.9998335450382971</td>
#       <td>0.010101383898823976</td>
#       <td>0.0001644717521340766</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.b)</b> Verifique qué ocurre si a la señal de $f_0 = f_S/4 + 0.5$ se le agregan ceros para prolongar su duración. Es decir si la señal tiene N muestras, agregue $M_j$ ceros siendo $M_j = ( \frac{N}{10},\, N,\, 10N)$.
# </div>

# %%
# Inserte aquí su código

N  = 1000 # muestras
fs = 1000 # Hz

##################
# a.4) Senoidal #
#################

a0 = 1     # Volts
p0 = 0     # radianes
#f0 = fs+10 # Hz

Offset = 0 #Volt


tus_resultados = []
                   
fd = 0.5

#Genero senoidal
tiempo, senial = mi_funcion_sen( a0, Offset, fs/4+fd, p0, N, fs)


mj=[0, N//10, N, N*10]
caso = {0: '0', mj[1]:'N/10', mj[2]:'N', mj[3]: 'N*10'} #Para Titulo del Plot

for nn in mj:
    
    #Realizo zero padding
    xx = np.concatenate((senial,np.zeros(nn)))
    #Calculo FFT y genero vector de frec
    ff = np.fft.fft(xx)
    modulo = np.abs(ff)/len(xx)
    frec = np.fft.fftfreq(len(xx),1/fs)

    #Grafico los resultados
    fig, [ax1,ax2] = plt.subplots(2,1)
    ax1.plot(xx)
    ax1.set_title('Zero Padding: '+caso[nn], fontsize='x-large')
    
    #fig, ax1 = plt.subplots()
    #ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
    ax2.stem(frec, 2*modulo, use_line_collection = True) #Escalo para solo lado derecho
    ax2.set_title('Espectro de la señal', fontsize='x-large')
    ax2.set_ylabel('Modulo []')
    ax2.set_xlabel('Frec [Hz]')
    plt.xlim(240, 260)
    
    ax1.grid(True)
    ax2.grid(True)

    
    #Cargo mis resultados
    deltaf = fs/len(xx)
    print(deltaf)
    f0 = np.argmax(modulo[:int(len(xx)/2)])
    f0 = frec[int(f0)]

    tus_resultados.append([f0, np.around(100*(f0-(fs/4+fd))/(fs/4+fd),2)])
# Out:
# 1.0
# 0.9090909090909091
# 0.5
# 0.09090909090909091

# %% [markdown]
# **3.c)** ¿Ha variado la resolución espectral en los casos de 3.b?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Si. La resolución espectral se ha incrementado (Delta f se hace mas chico)
# </div>

# %% [markdown]
# **3.d)** ¿Cuál es el efecto que se produce en cada caso? Esta técnica se conoce como Zero padding.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Podemos ver que al incrementar el zero padding, aumenta nuestra resolucion espectral. Para el caso donde la resolucion espectral coincide con nuestro desplazamiento fd podemos ahora ver el maximo de potencia en espectro coincidente con la frecuencia de nuestra señal senoidal. Esto probablemente también pueda lograrse con resoluciones espectrales que sean divisores de nuestro fd (0.1 ; 0.25; etc...)
#
# En el cuarto caso la resolucion espectral es tal que podemos observar con total claridad la curva del Kernel de Dirichlet de nuestro desparramo espectral
# </div>

# %% [markdown]
# **3.e)** Analice cuál es la frecuencia  $\hat{f}_0 = \mathop{arg\ max}_f \{\lvert X(f) \rvert \}$ a la que ocurre el máximo del espectro y en cuánto difiere de $f_0$ en términos porcentuales.

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

#tus_resultados = [['',''], # <-- acá debería haber numeritos :)
#                  ['',''], # <-- acá debería haber numeritos :)
#                  ['',''], # <-- acá debería haber numeritos :)
#                  ['',''] # <-- acá debería haber numeritos :)
#                 ]
df = DataFrame(tus_resultados, columns=['$f_0$', '$e_\%$'],
               index=['0',
                      '$N/10$', 
                      '$N$', 
                      '$10N$'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$f_0$</th>
#       <th>$e_\%$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>251.000000</td>
#       <td>0.20</td>
#     </tr>
#     <tr>
#       <th>$N/10$</th>
#       <td>250.909091</td>
#       <td>0.16</td>
#     </tr>
#     <tr>
#       <th>$N$</th>
#       <td>250.500000</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>$10N$</th>
#       <td>250.545455</td>
#       <td>0.02</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b>
# Para cada señal propuesta complete los valores que se indican en las siguientes consignas.
# </div>

# %% [markdown]
# + En la tabla de resultados de cada inciso, en la fila indicada con **predicción** responda conceptualmente qué contenido espectral debería obtener tras evaluar su FFT (sin realizar ninguna simulación).
# + Calcule su espectro y discuta la predicción con los resultados obtenidos de la **simulación**. Intente discutir las diferencias si las hubiera en las respuestas de cada inciso.
# + Preste especial atención en su discusión a:
#   * La energía total de la señal
#   * La energía del tono en particular
#   * La localización del tono en el espectro
# + Siga las indicaciones particulares para cada señal.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Las siguientes señales pueden generarse a partir de una senoidal *patrón* siguiendo las consignas de la derecha.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./1.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.a) Senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['1', '1', '9'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]
fn = 9
a0 = np.sqrt(2) #Potencia nornmalizada
#potenciasenial
#potencia

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)

ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 2*fn)

ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)


tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo))])

df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 1.0000000000000004
# 1.0000000000000007
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>1</td>
#       <td>1</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
# ...

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./2.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.b) **1 solo ciclo** de la misma senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''],
                  #['0.5', '0.5', '9'], # <-- completar acá
                  [str(1/9), str(1/9**2), '9'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]

fn = 9
ciclos = 1

potenciasenial
potencia

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[int(ciclos*N/fn):] = 0


ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
fase = np.angle(ff, True)
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.set_title('Señal temporal', fontsize='x-large')
ax1.grid(True)


fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 4*fn)

ax1.grid(True)

fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, fase, use_line_collection = True)
#ax1.set_title('Espectro de la señal')
ax1.set_ylabel('Angle [°]')
ax1.set_xlabel('Frec [K]')
ax1.grid(True)
plt.xlim(0, 4*fn)



potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo))])

df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 0.1111109502515177
# 0.11111095025151771
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>0.1111111111111111</td>
#       <td>0.012345679012345678</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Observe el resultado y compare sus resultados con el punto anterior. ¿Qué ha cambiado? ¿Cuánto vale la energía de un solo ciclo de senoidal respecto al caso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>En el primer caso donde teniamos nuestra señal de 9Hz en sintonia con nuestra ventana de 1 segundo en su espectro se reflejaba la totalidad de la energia de la señal contenida en el bin 9 como era de esperarse. En cambio al quedarnos con un unico ciclo de la señal, vemos en su espectro el resultado de haber multilpicado en el tiempo por una ventana rectangular 9 veces menor en tiempo. O sea, que nuestro espectro original ahora se encuentra convolucionado con un kernel de dirichlet cuyos lobulos son nueve veces mas anchos que el anterior (Donde los cruces por cero coincidian con las muestras y por eso solo veiamos la energia en su componente central) <br>
#      Otra cosa que sucede es un aparente corrimiento de la frecuencia central, cuyo máximo ahora parecería encontrarse en algún valor entre 7 y 8, más cerca de este último. </p>
#
# <p>En cuanto a la energía total de la señal, como era de esperarse podemos ver que vale una novena parte de la energia de la señal original. (Aunque esto no se haya predicho correctamente al momento previo de realizar el experimento) Para el caso particular de la energia contenida en la componente central del espectro, vemos que la relacion corresponde a dividir la original por 9² </p>
# <p style="color:#FF0000";>Se editaron valores esperados tras correción/normalización de potencia de la señal y a fines de verificar lo anteriormente explicado</p>
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./3.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.c) 1 solo ciclo de la misma senoidal
# 				de energía normalizada y frecuencia $f_0 = 9 \cdot f_S/N$ **pero demorado un tiempo igual a dos ciclos**. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  [str(1/9), str(1/9**2), '8'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]

fn = 9

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[:int(2*N/fn)] = 0
xx[int(3*N/fn):] = 0


ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
fase = np.angle(ff, True)
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.set_title('Señal Temporal', fontsize='x-large')
ax1.grid(True)

fig, ax1 = plt.subplots()
# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 4*fn)
ax1.grid(True)

fig, ax1 = plt.subplots()
# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, fase, use_line_collection = True)
#ax1.set_title('Espectro de la señal')
ax1.set_ylabel('Angle [°]')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 4*fn)
ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo))])

df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 0.11111073979416736
# 0.11111073979416736
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>0.1111111111111111</td>
#       <td>0.012345679012345678</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# En este caso, ¿Qué ha cambiado respecto al anterior? ¿Cómo se manifiesta en el dominio frecuencial?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>Podemos observar que al mover la ventana rectangular dos ciclos de nuestra señal senoidal no se presenta ningun cambio en el modulo del espectro. Si podemos ver reflejado este cambio en su fase, que graficamos fin de evidenciar lo aquí expuesto</p>
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./4.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.d) 1 solo ciclo de la misma senoidal utilizada hasta ahora, y otro ciclo de idénticas características pero de $f_1 = 8 \cdot f_S/N$ y demorado aproximadamente como se observa a la izquierda. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  [str(1/9+1/8), str(1/9**2), '8'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]

fn = 8

potenciasenial
potencia

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[:int(2*N/fn)] = 0
xx[int(3*N/fn):] = 0

fn = 9

tiempo, xx2 = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx2[int(1*N/fn):] = 0

xx += xx2

ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.set_title('Señal Temporal', fontsize='x-large')
ax1.grid(True)


fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 100)

ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo[:int(N/2)]))])

df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática',
                      '', 
                      '',
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 0.2361109502515178
# 0.2361109502515178
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>0.2361111111111111</td>
#       <td>0.012345679012345678</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %%
xx = np.concatenate((xx,np.zeros(nn)))

ff = np.fft.fft(xx)
modulo = np.abs(ff)/len(xx)
frec = np.fft.fftfreq(len(xx),1/N)
# frec = np.fft.fftfreq(len(xx),1/len(xx))

fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal + Zero Padding', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 30)


ax1.grid(True)

# %% [markdown]
# ¿Puede localizar ambas componentes en este espectro? ¿Cómo lo haría?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>Siendo la tranformada de Fourier una operacion lineal lo que tenemos en este caso es la suma de los espectros de cada tono de 8 y 9Hz con sus respectivas ventanas. O sea que lo que vemos en el espectro es la suma de dos kernel de dirichlet cuya frecuencia central difiere en tan solo 1Hz (que corresponde a un bin en este caso).<br>
#     Aunque aumentemos la resolución espectral realizando un zero padding no se logra a distinguir ambas componentes principales de cada tono. Sí observarmos con mayor detalle la curva resultante de la suma de los dos kernel de dirichlet evidenciando la suma de ambas componentes.</p>
#     <p>Otro aspecto a mencionar, es que con las experiencias anteriores pudo predecirse con exito la energía de la señal, calculando el aporte de 1/9 + 1/8 = 0.236</p>
#     <p style="color:#FF0000";>Se modificaron valores a nuevo valor de potencia normalizada</p>
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./5.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.e) Idéntico al caso anterior salvo que se invierte la ocurrencia de las señales. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['0.236', '0.0157', '8'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]

fn = 9

potenciasenial
potencia

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[:int(2*N/fn)] = 0
xx[int(3*N/fn):] = 0

fn = 8

tiempo, xx2 = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx2[int(1*N/fn):] = 0

xx += xx2

ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.set_title('Señal Temporal', fontsize='x-large')
ax1.grid(True)


fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 100)

ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo[:int(N/2)]))])

df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 0.23611073979416736
# 0.23611073979416738
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>0.236</td>
#       <td>0.0157</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
# ...

# %%
xx = np.concatenate((xx,np.zeros(nn)))

ff = np.fft.fft(xx)
modulo = np.abs(ff)/len(xx)
frec = np.fft.fftfreq(len(xx),1/N)
# frec = np.fft.fftfreq(len(xx),1/len(xx))

fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal + Zero Padding', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 30)


ax1.grid(True)

# %% [markdown]
# ¿ha cambiado el espectro respecto al caso anterior? ¿Si solo dispone del espectro, puede decir cuál ha ocurrido antes? ¿Resulta útil el análisis de espectral mediante la transformada de Fourier en este caso?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>Se verifica que ha cambiado al observar el bin donde se encuentra el "máximo" de potencia. Al observar los espectros con zero padding podemos ver que son ligeramente distintos. Pareciera que a partir de tan solo el modulo del espectro fuera posible indicar cual tono se presentó antes en el tiempo. </p>
#
#     -Recordar que estamos sumando numeros complejos con modulo y fase-
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./6.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.f) Arme una señal como la que se muestra a la izquierda, concatenando 3 ciclos de $f_0 = 9 \cdot f_S/N$.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  [str(3/9), str((3/9)**2), '9'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]

fn = 9
ciclos = 3

potenciasenial
potencia

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[int(ciclos*N/fn):] = 0


ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.set_title('Señal Temporal', fontsize='x-large')
ax1.grid(True)

fig, ax1 = plt.subplots()
# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal', fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 2*fn)
ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo))])
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 0.33333254382107563
# 0.3333325438210757
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>0.3333333333333333</td>
#       <td>0.1111111111111111</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con la señal donde los 9 ciclos estaban presentes? ¿Y respecto a la que solo había 1 ciclo?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>La energía en $f_0$ corresponde a una novena parte de la energía que concentraba dicha componente cuando estaban los 9 ciclos presentes. Podria interpretarse que dicha relacion surge de dividir por 3², donde el 3 corresponde a que ahora tenemos un 1/3 de la señal.<br>
#     Esto mismo se cumple para 1 ciclo, donde la componente $f_0$ corresponde a $1/9$ parte de la presente en el caso de los 3 ciclos de señal. $(0.0555/9 = 0,006172)$</p>
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./7.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.g) Idem anterior, pero cada ciclo con amplitudes (1, 5, 3).</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  #['0.5', '0.216', '9'], # <-- completar acá
                  [str((1**2/9)+(5**2/9)+(3**2/9)),'?','9'],
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]
fn = 9

potenciasenial
potencia

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[int(1*N/fn):] = 0               
                  
tiempo, xx2 = mi_funcion_sen( 5*a0, Offset, fn*fs/N, p0, N, fs)
xx2[:int(1*N/fn)] = 0
xx2[int(2*N/fn):] = 0

tiempo, xx3 = mi_funcion_sen( 3*a0, Offset, fn*fs/N, p0, N, fs)
xx3[:int(2*N/fn)] = 0
xx3[int(3*N/fn):] = 0

xx += xx2
xx += xx3
                  
ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.grid(True)


fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 2*fn)

ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo[:int(N/2)]))])                  
                  
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 3.888878952783789
# 3.8888789527837893
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>3.888888888888889</td>
#       <td>?</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
# ...

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p> A nuestra energia de 0.5 que poseiamos con 9 ciclos completos debimos multiplicarla por (25/9 + 1/9 + 9/9) para llegar a los 1.944 actuales. Sacando factor común 1/3 rapidamente podemos calcular que tenemos 35/3 veces la energía obtenida en el inciso anterior. </p>
#
# <p>Para el caso de la energía en la componente $f_0$ pareciera ser 9 veces la anterior.</p>
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./8.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.h) Idem patrón anterior, pero repetido 3 veces.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  [str(3*((1**2/9)+(5**2/9)+(3**2/9))), '3', '9'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]

fn = 9

potenciasenial
potencia

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[int(1*N/fn):int(3*N/fn)] = 0
xx[int(4*N/fn):int(6*N/fn)] = 0
xx[int(7*N/fn):int(9*N/fn)] = 0
                  
tiempo, xx2 = mi_funcion_sen( 5*a0, Offset, fn*fs/N, p0, N, fs)
xx2[:int(1*N/fn)] = 0
xx2[int(2*N/fn):int(4*N/fn)] = 0
xx2[int(5*N/fn):int(7*N/fn)] = 0
xx2[int(8*N/fn):] = 0

tiempo, xx3 = mi_funcion_sen( 3*a0, Offset, fn*fs/N, p0, N, fs)
xx3[:int(2*N/fn)] = 0
xx3[int(3*N/fn):int(5*N/fn)] = 0
xx3[int(6*N/fn):int(8*N/fn)] = 0

xx += xx2
xx += xx3
                  
ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.set_title('Señal Temporal', fontsize='x-large')                       
ax1.grid(True)


fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal',fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 2*fn)

ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo[:int(N/2)]))])
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 11.666646196899215
# 11.666646196899213
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>11.666666666666666</td>
#       <td>3</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
# ...

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior? ¿Y respecto al que estaban los 9 ciclos presentes pero con la misma amplitud?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>Respecto del caso anterior tenemos 9 veces su energía. Similar resultado que para 9 ciclos de amplitud unitaria</p>
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./9.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.i) En este caso genere un ciclo de $f_0 = 9 \cdot f_S/N$, y seguido otro ciclo pero desfasado $\pi$ radianes.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  #['0.111', '0.0247', '9'], # <-- completar acá
                  [str(2/9), str((2/9)**2), '9'], # <-- completar acá
                  ['', '', ''], 
                  #['', '', '']  # <-- completar acá
                 ]

fn = 9

potenciasenial
potencia

p0 = 0

tiempo, xx = mi_funcion_sen( a0, Offset, fn*fs/N, p0, N, fs)
xx[int(1*N/fn):] = 0               

p0 = np.pi

tiempo, xx2 = mi_funcion_sen(a0, Offset, fn*fs/N, p0, N, fs)
xx2[:int(1*N/fn)] = 0
xx2[int(2*N/fn):] = 0


xx += xx2
                  
ff = np.fft.fft(xx)
modulo = np.abs(ff)/N
frec = np.fft.fftfreq(N,1/N)

fig, ax1 = plt.subplots()
ax1.plot(tiempo, xx)
ax1.set_title('Señal Temporal', fontsize='x-large')
ax1.grid(True)


fig, ax1 = plt.subplots()

# ax1.stem(frec, 20*np.log10(modulo), use_line_collection = True)
ax1.stem(frec, modulo, use_line_collection = True)
ax1.set_title('Espectro de la señal',  fontsize='x-large')
ax1.set_ylabel('Modulo []')
ax1.set_xlabel('Frec [K]')
plt.xlim(0, 4*fn)

ax1.grid(True)

potenciasenial = (np.mean(xx**2))
print(potenciasenial)
potencia = (np.sum(modulo**2))
print(potencia)

tus_resultados.append([str(potencia),str(2*modulo[fn]**2), str(np.argmax(modulo[:int(N/2)]))])                  
                  
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# 0.22222180402690833
# 0.22222180402690836
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>0.2222222222222222</td>
#       <td>0.04938271604938271</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el que estaba un solo ciclo presente?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>En este caso la componente $f_0$ es nula.</p> <p>Nuevamente recordemos que estamos tratando con la suma de espectros complejos,y en este caso exactamente a contrafase. Esta suma de números complejos produce que justo en la frecuencia de los senos se anule la componente en modulo</p>
# </div>

# %% [markdown]
# Luego de realizar la experimentación y observando los resultados obtenidos discuta si es fiable o no medir en el dominio de Fourier, por medio de la FFT los siguientes aspectos de una señal:
#
#     • Energía
#     • Contenido espectral
#     • Energía de un determinado ancho de banda o componente espectral
#     • Localización temporal de un determinado componente espectral.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Respuesta:</b> <p>Es completamente fiable medir energía por medio de la FFT.<br>
#     Debe interpretarse correctamente que se está observando para evaluar contenido espectral por medio de la FFT<br>
#     No es del todo fiable determinar la energía de una componente en particular a través de la FFT <br>
#     Un desplazamiento temporal equivale a un producto por una exponencial compleja en dominio frecuencial. Se comprobó el cambio del espectro al aplicar un desplazamiento temporal al ciclo de señal
#     </p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b>
# Simule el efecto de cuantizar una señal continua en el tiempo mediante un conversor analógico digital (ADC).
# </div>

# %% [markdown]
# Para ello analice señales determinísticas, por ejemplo una senoidal de **energía normalizada** y frecuencia $f_0$, y otras que varíen de forma más aleatoria y por lo tanto, representativa de una señal real, por ejemplo añadiendo ruido. Es decir que la señal *real* simulada será
#
# $$s_R = s + n$$
#
# donde la señal $n$ debe tener una energía de $1/10$.
#
# Puede simular una señal continua (aproximadamente para los fines prácticos), mediante una señal muestreada a una $f^1_S$ muy alta en comparación con las $f_S$  que quiere estudiar, y un tipo de dato de doble precisión (double o float de 64 bits). De esta manera se asegura una grilla de cuantización (en tiempo y amplitud) mucho más densa que la que se va a simular. Se pide cuantizar a palabras de 4, 8 y 16 bits, obteniendo
#
# $$ s_Q = \mathop{Q}_i \{s_R\} \quad i \in (4, 8, 16) $$
#
# Siendo $\mathop{Q}_i$ la función **no lineal** responsable de la cuantización a *i-* bits de la señal real $s_R$. Describa el ruido de cuantización
#
# $$ e = s_Q - s_R$$
#
# para las 3 situaciones antedichas siguiendo las siguientes consignas.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.a)</b>
# La señal temporal $e$ y su espectro $E$.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

def ADC(xx,fs,sps, bits):
    '''Simula el muestro y cuantizacion al digitalizar una señal
        La señal debe encontrarse entre 0 y 1V

    Keyword arguments:
    xx -- senñal a digitalizar
    fs -- Frecuencia de Sampleo de la señal original.
    sps -- samples per second (frec muestreo del ADC)
    bits -- bits de resolucion del ADC                          

    Returns: array of float, array of float

    '''
    
    Ts = int(fs/sps)
    digital_xx = (xx[::Ts])
    digital_xx= np.rint(digital_xx*(2**bits-1))
    
    #Saturacion
    digital_xx = [2**bits-1 if muestra>2**bits-1 else muestra for muestra in digital_xx]
    #recorte
    digital_xx = [0 if muestra<0 else muestra for muestra in digital_xx]
    
    return np.array(digital_xx)


# NO modifiques este bloque
############################

N  = 10000 # muestras
fs = 1000 # Hz

##################
# a.4) Senoidal #
#################

a0 = np.sqrt(2)    # Volts
p0 = 0     # radianes
#f0 = fs+10 # Hz

Offset = 0 #Volt

#################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$' ], 
                   ['',                                             '',                                             ''                              ], 
                   #['', '', ''], # <-- completar acá
                   #['', '', ''], # <-- completar acá
                   #['', '', ''], # <-- completar acá
                 ]

fd = 0

#Parametros ruido
mean = 0
var = 0.1

potencia = []
e = []
e_list = []

tiempo, xx = mi_funcion_sen( a0, Offset, fs/100+fd, p0, N, fs)
#ruido = GaussNoise(len(xx),0,0.1)
ruido = np.random.normal(mean,np.sqrt(var),N)

corr = np.correlate(ruido,ruido, mode='same')
potenciaruido = corr[int(N/2)]/len(corr)
potencia = np.mean(xx**2)
print(potencia)
print(potenciaruido)

xx += ruido
potencia = np.mean(xx**2)


################################################
##  Adecuacion de la señal para el ADC
################################################
continua = 0.5

xx /= 2*np.max(xx)
xx += continua

################################################

bits = [4, 8, 16]
plt.figure()
#fig1, axes = plt.subplots(1,3)

for nn,ax in zip(bits,range(1,len(bits)+1)):

    digital = ADC(xx,fs,fs/10,nn)
    
    #e = (2**nn-1)*xx[::10] - digital
    e = xx[::10] - digital/(2**nn-1)
    e_list.append(e)
    
    
    plt.figure(1)
    plt.subplot(3, 1, ax)
    plt.plot(tiempo,xx,'g',label='analogica')
    plt.title('Señal Analogica Vs Digital '+str(nn)+ 'bits', fontsize='x-large')
    plt.stem(tiempo[::10], digital/(2**nn-1),label='digital', use_line_collection = True)
    # ax1.plot(tiempo[::10], digital,label='digital')
    plt.xlim(0,1) #Se aplica zoom para poder apreciar la señal a pesar del aumento de muestra
    plt.legend()
    
    plt.figure()
    plt.subplot(1, 2, 1)
    plt.plot(tiempo[::10],e)
    plt.hlines(1/(2*(2**nn)),tiempo[0],tiempo[-1],color='red',linestyles='dashed',label='q/2')
    plt.hlines(-1/(2*(2**nn)),tiempo[0],tiempo[-1],color='red',linestyles='dashed',label='-q/2')
    plt.title('Ruido de cuantización '+str(nn)+' bits', fontsize = 'xx-large')
    plt.ylabel('Amplitud []')
    plt.xlabel('tiempo [t]')
    plt.ylim(-0.04,0.04)
    plt.grid()
    
    plt.subplot(1, 2, 2)
    e = np.correlate(list(e),list(e), mode='full')
    ff = np.fft.fft(e)
    modulo = np.abs(ff)/len(e)
    frec = np.fft.fftfreq(len(e),1/N)
    modulo=np.fft.fftshift(modulo)
    frec=np.fft.fftshift(frec)
    plt.plot(frec,modulo)
    plt.title('Espectro Ruido Q: '+str(nn)+' bits', fontsize = 'xx-large')
    plt.ylabel('Amplitud []')
    plt.xlabel('Frec [k]')
    plt.xlim(0)
 
    
    
    plt.grid(True)
    #ax1.legend(loc='upper right', fontsize = 'xx-large')  # Add a legend.
  
    tus_resultados.append([str(potencia), str(np.mean(digital**2)/(2**nn-1)**2), str(np.mean(e**2))])

df = DataFrame(tus_resultados, columns=['Energía total', 'Energía total Q', 'Energía total $e$'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# 1.0
# 0.09889507733320203
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía total Q</th>
#       <th>Energía total $e$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4 bits</th>
#       <td>1.1103009826666335</td>
#       <td>0.2906888888888889</td>
#       <td>0.00012882574459957907</td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td>1.1103009826666335</td>
#       <td>0.28980218377547096</td>
#       <td>1.6376220639361826e-09</td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.b)</b> El histograma de la señal $e_i$ para cada tamaño de palabra.
# </div>

# %%
#####################################
# Tu simulación que genere gráficas #
#####################################
bins = 10

for i,nn in zip(np.arange(3),bits):
    q = 1/(2**nn)
    var_calculada = (q**2)/12
    print('Energía/Varianza esperada = ', var_calculada)
    plt.figure()
    plt.hist(e_list[i], bins=bins ,label='Señal estudiada')  # arguments are passed to np.histogram
    plt.hlines(len(e_list[i])/bins,min(e_list[i]),max(e_list[i]),linestyles='dashed',color='red',label="Uniforme ideal")
    plt.title('Histograma $e_q$(%i bits)' %nn, fontsize = 'xx-large')
    plt.ylabel('Ocurrencias')
    plt.xlabel('Valor e')
    plt.legend()
# Out:
# Energía/Varianza esperada =  0.0003255208333333333
# Energía/Varianza esperada =  1.2715657552083333e-06
# Energía/Varianza esperada =  1.9402553637822468e-11

# %% [markdown]
# ¿Qué información podemos obtener de esta forma de analizar la señal $e_i$?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> <p>Para la cantidad de muestras utilizadas y los bins seleccionados no llega a apreciarse una distribución bien definida. Si puede señalarse que es consistente con el tipo de distribucion esperada (uniforme).</p>
#     <p>Recordemos que este ruido es producto de la cuantización, y no el ruido con distribución normal añadido a la senoidal</p>
#     <p style="color:rgb(255,0,0);">Tras aumentar el numero de N se puede apreciar la distribucion uniforme del error por cuantización</p>
#     <p style="color:rgb(255,0,0);">Se imprimió el valor de Energía calculada a través de la formula de varianza para  una distribucion uniforme. $Var\{N_q\}=q²/12$</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.c)</b> Una descripción de la señal $e_i$, por medio del **valor medio**, su valor **RMS** y su energía **energía**
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   #['', '', ''], # <-- completar acá
                   #['', '', ''], # <-- completar acá
                   #['', '', ''], # <-- completar acá
                 ]

for i in np.arange(3):
    tus_resultados.append([np.mean(e_list[i]), np.sqrt(np.mean(e_list[i]**2)), np.mean(e_list[i]**2)])

df = DataFrame(tus_resultados, columns=['Valor medio', 'RMS', 'Energía'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor medio</th>
#       <th>RMS</th>
#       <th>Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td>-9.166820e-04</td>
#       <td>0.019172</td>
#       <td>3.675609e-04</td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td>3.233761e-05</td>
#       <td>0.001130</td>
#       <td>1.277517e-06</td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td>8.003320e-08</td>
#       <td>0.000004</td>
#       <td>1.943334e-11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.d)</b> Una descripción **estadística** de la señal $e_i$, por medio de su **media**, su **desvío estándard** y su energía **varianza**.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################


tus_resultados = [ 
                   #['', '', ''], # <-- completar acá
                   #['', '', ''], # <-- completar acá
                   #['', '', ''], # <-- completar acá
                 ]

for i in np.arange(3):
    tus_resultados.append([np.mean(e_list[i]), (np.std(e_list[i])), np.var(e_list[i])])

df = DataFrame(tus_resultados, columns=['Media', 'Desvío estándard', 'Varianza'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Media</th>
#       <th>Desvío estándard</th>
#       <th>Varianza</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td>-9.166820e-04</td>
#       <td>0.019150</td>
#       <td>3.667206e-04</td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td>3.233761e-05</td>
#       <td>0.001130</td>
#       <td>1.276472e-06</td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td>8.003320e-08</td>
#       <td>0.000004</td>
#       <td>1.942694e-11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Discutir las similitudes y diferencias con los parámetros calculados en **c)** y **d)**.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Respuesta:</b> <p>Lo primero que podemos notar de ambas caracterizaciones es que hablar de la varianza de una señal aleatoria es equivalente a hablar de la energía de la misma, como ya sabíamos antes del experimento. Observamos que es aproximado a los valores esperados calculados en el punto anterior. </p>
#     <p>También pudo comprobarse que hablar de Desviación estandar es equivalente a referirse al valor RMS de la señal</p>
#     <p>El valor medio está presente en ambas caracterizaciones y como era de esperarse el mismo tiende a 0. </p>
# </div>
